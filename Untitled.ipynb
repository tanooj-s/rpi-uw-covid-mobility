# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('outputforwebsite.data')

# %%
df.sample(20)
# Out:
#            Statename   FIPS       Date   Days_from_Ref   RelativeMobility  \
# 1125           Texas     48   2020-5-5              43         -32.333333
# 4505  North Carolina     37  2020-8-15             137                NaN
# 1432            Ohio     39  2020-5-14              35         -28.333333
# 3598      New Jersey     34  2020-7-19             108         -22.000000
# 4179         Alabama      1   2020-8-5             129         -10.666667
# 4418            Iowa     19  2020-8-12             130                NaN
# 5188    Pennsylvania     42   2020-9-5             151                NaN
# 2655         Indiana     18  2020-6-20              73           3.000000
# 5352        Illinois     17  2020-9-10             156                NaN
# 1390         Florida     12  2020-5-13              50         -38.333333
# 1857         Georgia     13  2020-5-27              70         -31.000000
# 5491            Ohio     39  2020-9-14             158                NaN
# ...

# %%
# Out:
# Index(['Statename', ' FIPS', ' Date', ' Days_from_Ref', ' RelativeMobility',
#        ' CumulativeMobility', ' Actual-Predict', ' FatalityRA',
#        ' CumFatality_Stayput', ' SchoolOpenNow1%', 'SchoolOpenNow2%',
#        'MaskMandate25%', ' MaskMandate50%', ' Shutdown1week', ' Shutdown2week',
#        ' Population'],
#       dtype='object')

# %%
df.dropna(subset=[" Shutdown2week"])
# Out:
#          Statename   FIPS       Date   Days_from_Ref   RelativeMobility  \
# 4521      New York     36  2020-8-16             140                NaN
# 4522    New Jersey     34  2020-8-16             136                NaN
# 4523    California      6  2020-8-16             137                NaN
# 4524         Texas     48  2020-8-16             146                NaN
# 4525       Florida     12  2020-8-16             145                NaN
# ...            ...    ...        ...             ...                ...
# 6133  Rhode Island     44  2020-10-3             169                NaN
# 6134          Iowa     19  2020-10-3             182                NaN
# 6135      Oklahoma     40  2020-10-3             176                NaN
# 6136      Kentucky     21  2020-10-3             186                NaN
# 6137            US      0  2020-10-3             186                NaN
#
#        CumulativeMobility  Actual-Predict   FatalityRA   CumFatality_Stayput  \
# ...
